# %%
from dnd.new_data_preparation import *

result1 = test_softmax()
result2= test(rows_per_batch=100000, batches=3, epochs = 20, rows_of_test_data = 100, simulation_iterations=1000)
# Out:
# 2021-07-11 16:54:35.875075: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-07-11 16:54:40.580535: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/20
# 313/313 [==============================] - 1s 724us/step - loss: 0.3881 - accuracy: 0.8169
# Epoch 2/20
# 313/313 [==============================] - 0s 768us/step - loss: 0.3458 - accuracy: 0.8393
# Epoch 3/20
# 313/313 [==============================] - 0s 666us/step - loss: 0.3359 - accuracy: 0.8477
# Epoch 4/20
# 313/313 [==============================] - 0s 656us/step - loss: 0.3290 - accuracy: 0.8519
# Epoch 5/20
# ...

# %%
# Out:
#     model_pct_chance_for_char1  model_pct_chance_for_char2  \
# 0                     0.841839                1.581606e-01
# 1                     0.574780                4.252204e-01
# 2                     1.000000                9.632765e-09
# 3                     0.070791                9.292095e-01
# 4                     0.765357                2.346429e-01
# ..                         ...                         ...
# 95                    0.027897                9.721033e-01
# 96                    0.692972                3.070276e-01
# 97                    0.467446                5.325541e-01
# 98                    1.000000                3.548106e-09
# 99                    0.874012                1.259882e-01
#
#     sim_pct_chance_for_char1  sim_pct_chance_for_char2  char1_won  char2_won  \
# 0                      0.901                     0.099          1          0
# 1                      0.726                     0.274          1          0
# ...

# %%
result1
# Out:
#     model_pct_chance_for_char1  model_pct_chance_for_char2  \
# 0                     0.841839                1.581606e-01
# 1                     0.574780                4.252204e-01
# 2                     1.000000                9.632765e-09
# 3                     0.070791                9.292095e-01
# 4                     0.765357                2.346429e-01
# ..                         ...                         ...
# 95                    0.027897                9.721033e-01
# 96                    0.692972                3.070276e-01
# 97                    0.467446                5.325541e-01
# 98                    1.000000                3.548106e-09
# 99                    0.874012                1.259882e-01
#
#     sim_pct_chance_for_char1  sim_pct_chance_for_char2  char1_won  char2_won  \
# 0                      0.901                     0.099          1          0
# 1                      0.726                     0.274          1          0
# ...

# %%
result2
# Out:
#     model_pct_chance_for_char1  sim_pct_chance_for_char1  \
# 0                     0.568435                     0.722
# 1                     0.000008                     0.000
# 2                     0.064201                     0.076
# 3                     0.018746                     0.013
# 4                     0.079100                     0.197
# ..                         ...                       ...
# 95                    0.812050                     0.767
# 96                    0.409228                     0.559
# 97                    0.002223                     0.000
# 98                    0.999991                     1.000
# 99                    0.041493                     0.066
#
#     sim_pct_chance_for_char2  char1_won  char2_won  winner  remaining_hp
# 0                      0.278          1          0       1            27
# 1                      1.000          0          1       2            29
# ...
